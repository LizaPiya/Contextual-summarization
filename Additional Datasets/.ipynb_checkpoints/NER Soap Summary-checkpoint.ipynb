# %%
import pandas as pd
df_sample = pd.read_csv("sample_summary.csv")
# Display the first few rows
print(df_sample.head())

# Check DataFrame info
print(df_sample.info())
# Out:
#                                                input  \
# 0  Good afternoon, champ, how you holding up? Goo...
# 1  What brings you in here today? Hi, I'm um, I'm...
# 2  Do you have any known allergies to medications...
# 3  How may I help you today? Yeah I've had, a fev...
# 4  It sounds like that you're experiencing some c...
#
#                                               output
# 0  Subjective:\n- Symptoms: Lower back pain, radi...
# 1  Subjective:\n- Presenting with dry cough for 1...
# 2  Subjective:\n- No known allergies to medicatio...
# 3  Subjective:\n- Fever and dry cough started 4 d...
# 4  Subjective:\n- Presenting with chest pain for ...
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   input   100 non-null    object
#  1   output  100 non-null    object
# dtypes: object(2)
# memory usage: 1.7+ KB
# None

# %%
print(df_sample['output'].iloc[9])
# Out:
# Subjective:
# - Presenting with cough that started yesterday, wet cough with yellowish-green sputum that smells bad and leaves a bad taste in mouth
# - Shortness of breath started within last 12 hours, has been worsening
# - Shortness of breath worse with smoking cigarettes and going out to get mail, had to sit down due to inability to get mail which is unusual
# - Feels heart has been beating a little faster
# - Felt a little nauseous with the bad taste in mouth
# - No headache, runny nose, congestion, chest pain, abdominal pain, nausea, vomiting, diarrhea, constipation, or sore throat
#
# PMHx:
# - Hypertension
# - GERD - still gets heartburn and acid in mouth at times despite PPI, worse with certain foods
# - Hyperlipidemia
# - Anxiety - no panic attacks
# - Left knee replacement a few years ago
#
# Medications: ACE inhibitor, statin, pantoprazole
#
# SocHx:
# - Retired
# - Drinks 4-6 beers daily, had more than usual yesterday and friends reported he passed out drunk
# - Smokes 0.5 PPD cigarettes, down from 1 PPD previously
# - Denies marijuana or recreational drug use
# - Lives with wife in apartment, able to do grocery shopping and household chores, uses cane at times due to previous knee injury
#
# FHx:
# - Father had liver disease (passed away from this) and heart problems, was a lifelong smoker
#
# Objective:
# - Vitals signs
# - Respiratory examination
#
# Assessment:
# - Possible aspiration pneumonia or viral pneumonia/infection
#
# Plan:
# - Chest X-ray
# - Labs
# - Likely start antibiotics
# - Recommend follow-up with PCP for regular check-ups, medication adjustments, and age-appropriate screenings

# %%
import pandas as pd
import uuid

# Assuming df_sample is your DataFrame
# Generate a new column 'id' with a UUID for each row
df_sample['id'] = df_sample.apply(lambda x: str(uuid.uuid4()), axis=1)

# %%
df_sample.head(5)
# Out:
#                                                input  \
# 0  Good afternoon, champ, how you holding up? Goo...
# 1  What brings you in here today? Hi, I'm um, I'm...
# 2  Do you have any known allergies to medications...
# 3  How may I help you today? Yeah I've had, a fev...
# 4  It sounds like that you're experiencing some c...
#
#                                               output  \
# 0  Subjective:\n- Symptoms: Lower back pain, radi...
# 1  Subjective:\n- Presenting with dry cough for 1...
# 2  Subjective:\n- No known allergies to medicatio...
# 3  Subjective:\n- Fever and dry cough started 4 d...
# 4  Subjective:\n- Presenting with chest pain for ...
#
#                                      id
# 0  d3f29f4c-d851-4cfb-8845-5d6aa68c49fb
# 1  37627204-129c-4588-a852-900458f4de08
# 2  47c797bf-332d-4809-a259-44c2e064adf4
# 3  bef04717-df21-4be7-aa7e-d7c1f80ea9f0
# 4  11348c49-156c-48a8-8f54-5a480d0aa8da

# %%
# !pip install -q huggingface_hub
from huggingface_hub import login
import os

# Use token from environment variable (safer)
login(os.getenv("HF_TOKEN"))

# %%
# !pip install -q transformers

# %%
from transformers import AutoTokenizer, AutoModelForTokenClassification, pipeline
import pandas as pd
import torch
from tqdm import tqdm

class SoapNERProcessor:
    def __init__(self, confidence_threshold: float = 0.75, max_token_length: int = 512, overlap: int = 50):
        """
        Initialize the SoapNERProcessor with a specified confidence threshold.
        Uses the samrawal/bert-base-uncased_clinical-ner model for NER.
        """
        print("\nInitializing SOAP NER Processor...")
        self.model_name = "samrawal/bert-base-uncased_clinical-ner"
        self.tokenizer = AutoTokenizer.from_pretrained(self.model_name)
        self.model = AutoModelForTokenClassification.from_pretrained(self.model_name)
        self.confidence_threshold = confidence_threshold
        self.max_token_length = max_token_length
        self.overlap = overlap

        device = 0 if torch.cuda.is_available() else -1
        self.ner_pipeline = pipeline(
            "ner",
            model=self.model,
            tokenizer=self.tokenizer,
            aggregation_strategy="simple",
            device=device
        )
        print("NER pipeline initialized successfully")

    def preprocess_text(self, text: str):
        return str(text).strip() if text else ""

    def split_text_into_chunks(self, text: str):
        """
        Split text into manageable chunks for NER processing to avoid exceeding the model's token limit.
        """
        chunks = []
        tokens = self.tokenizer.tokenize(text)
        max_chunk_size = self.max_token_length - self.overlap
        for i in range(0, len(tokens), max_chunk_size):
            chunk_tokens = tokens[i:i + self.max_token_length]
            chunks.append(self.tokenizer.convert_tokens_to_string(chunk_tokens))
        return chunks

    def extract_entities(self, text: str):
        """
        Extract entities from the clinical summary using the NER pipeline.
        """
        text = self.preprocess_text(text)
        if not text:
            return {"PROBLEM": [], "TREATMENT": [], "TEST": []}

        chunks = self.split_text_into_chunks(text)
        entities = {"PROBLEM": [], "TREATMENT": [], "TEST": []}
        for chunk in chunks:
            ner_results = self.ner_pipeline(chunk)
            for entity in ner_results:
                if entity['score'] > self.confidence_threshold:
                    entity_type = entity['entity_group'].upper()
                    entities[entity_type].append(entity['word'].replace("##", ""))

        return {k: list(set(v)) for k, v in entities.items()}

if __name__ == "__main__":
    print("\n=== Starting NER Processing for SOAP Data ===")
    processed_df = process_dataframe(
        df=df_sample,  
        text_column='output',  
        confidence_threshold=0.75  # Adjust as necessary
    )

    print("\nResults preview:")
    print(processed_df[['problems', 'treatments', 'tests']].head())
# Out:
# === Starting NER Processing for SOAP Data ===
#
# Initializing SOAP NER Processor...
# Device set to use cuda:0
# NER pipeline initialized successfully
#
# Results preview:
#                                             problems  \
# 0  [radiculopathy, the pain, weakness in the legs...
# 1  [known sick contacts, flu - like illness, ning...
# 2                                  [known allergies]
# 3  [hee, sp, blood, symptoms, w, um, viral infect...
# 4  [significant stress, chronic conditions, curre...
#
#                                           treatments  \
# 0  [anti - inflammatory medications, treatments, ...
# 1  [appendect, omy, infection control measures, o...
# 2                                      [medications]
# 3                                     [multivitamin]
# 4                [advil, tu, ms, tylenol, treatment]
#
#                                                tests
# 0  [differential diagnoses, x - rays of the lower...
# 1                         [sw, covid, swab, testing]
# 2                                                 []
# 3                         [covid, swab, temperature]
# 4  [physical examination, s signs, vital, assessm...

# %%
processed_df = processed_df.drop(['lifestyle', 'family_history', 'medications'], axis=1)

# %%
processed_df.head(40)
# Out:
#                                                 input  \
# 0   Good afternoon, champ, how you holding up? Goo...
# 1   What brings you in here today? Hi, I'm um, I'm...
# 2   Do you have any known allergies to medications...
# 3   How may I help you today? Yeah I've had, a fev...
# 4   It sounds like that you're experiencing some c...
# 5   Hi there! What brings you in today? Guest_fami...
# 6   Are you allergic to anything? No, I am not all...
# 7   What brought you in today? Sure, I'm I'm just ...
# 8   What brings you in? Yeah, I'm just coming in w...
# 9   What brings you in today? Yeah, so I've had th...
# 10  Are you married? Yes. Who do you have in your ...
# 11  Have you had any surgeries in the past? No, none.
# 12  So let's see here. Any history of high blood p...
# 13  Do you know when was the last time you got a t...
# 14  Is there any history of heart disease in your ...
# 15  So, I am looking at your reports, you don't ha...
# 16  Hello, miss. How can I help you today? The nur...
# 17  Are you married, ma'am? Yes, to my wonderful h...
# 18  What brings you in? Hi, I've I've had this pai...
# 19  Any history of heart attack? No. Any chest pai...
# 20  What brings you in here today? I've had this p...
# 21  Any past medical history like any diabetes or ...
# 22  Good morning. How are you feeling today? I fee...
# 23  How's your asthma since you started using your...
# 24  Hey, what's going on with you today? Oh, I hav...
# 25  Anyone in the family had any medical issues? O...
# 26  How are you feeling today? I am feeling very t...
# 27  So, how much longer are you in juvie, young ma...
# 28  Welcome back. Thank you. You are back for a fo...
# 29  What brings you in here today? I've just been ...
# 30  So, how are feeling? You came here last time w...
# 31  Hello, are you translating for the patient tod...
# 32  Is this baby number two? Yes, this is baby num...
# 33  Do you smoke cigarettes? Yes. Do you drink alc...
# 34  What medications are you currently taking? I a...
# 35  Do you have any past or present medical condit...
# 36  Do you have a family history of any medical co...
# 37  I will ask some simple questions, okay? Hm How...
# 38  Uh, what brings you in here today? Yeah, so my...
# 39  Guest_clinician: How is the patient's conditio...
#
#                                                output  \
# 0   Subjective:\n- Symptoms: Lower back pain, radi...
# 1   Subjective:\n- Presenting with dry cough for 1...
# 2   Subjective:\n- No known allergies to medicatio...
# 3   Subjective:\n- Fever and dry cough started 4 d...
# 4   Subjective:\n- Presenting with chest pain for ...
# 5   Subjective:\n- Concern that the baby may have ...
# 6   Subjective:\n- No allergies reported (includin...
# 7   Subjective:\n- Chest pain\n- Duration: Started...
# 8   Subjective:\n- 4 yo M presents with right ear ...
# 9   Subjective:\n- Presenting with cough that star...
# 10  Subjective:\n- Patient is married and has a sp...
# 11  Subjective:\n- No past surgeries reported.\n\n...
# 12  Subjective:\n- No history of high blood pressu...
# 13  Subjective:\n- Patient does not remember the l...
# 14  Subjective:\n- Family history of heart disease...
# 15  Subjective:\n- The patient expresses relief ab...
# 16  Subjective:\n- Symptoms: Dizziness (general di...
# 17  Subjective:\n- Patient is married.\n- Expresse...
# 18  Subjective:\n- Right elbow pain, lateral aspec...
# 19  Subjective:\n- No history of heart attack.\n- ...
# 20  Subjective:\n- 1-month history of lower back p...
# 21  Subjective:\n- Patient does not recall any pas...
# 22  Subjective:\n- Patient feels good, considering...
# 23  Subjective:\n- Symptoms: Asthma\n- Severity: M...
# 24  Subjective:\n- Chief complaint: chest pain\n- ...
# 25  Subjective:\n- Patient's mother's side family ...
# 26  Subjective:\n- Symptoms: Feeling very tired, d...
# 27  Subjective:\n- Patient is currently in juvenil...
# 28  Subjective:\n- Symptoms: Dull pain in the uppe...
# 29  Subjective:\n- Shortness of breath since this ...
# 30  Subjective:\n- The patient is recovering well ...
# 31  Subjective:\n- Patient is a 52-year-old male.\...
# 32  Subjective:\n- Patient is pregnant with baby n...
# 33  Subjective:\n- Patient smokes cigarettes.\n- P...
# 34  Subjective: \n- Patient is diabetic. \n- Curre...
# 35  Subjective:\n- No past or present medical cond...
# 36  Subjective:\n- Patient has no family history o...
# 37  Subjective:\n- Symptoms: Weakness, extreme tir...
# 38  Subjective:\n- 3 yo F presents with hoarse voi...
# 39  Subjective:\n- The patient has improved clinic...
#
#                                       id  \
# 0   39a26c55-f710-4272-8609-2a725ef6d068
# 1   b1448089-3c41-423a-9737-0ed25e0e99c8
# 2   78cf9b57-3a1f-41df-ba55-af3bbe843228
# 3   44be7957-be23-4cc9-a5e2-cb7139dc2079
# 4   3324cd95-1729-4b0b-8916-dba010ac811e
# 5   78fbdd2e-ed8e-45f9-a8c1-ae3c82861f83
# 6   2aebdcda-bb2f-4967-8426-9e216c02cd14
# 7   d1f2e65d-dcdc-41a2-8208-0e0130b72489
# 8   14d8c634-8731-4d2f-ba4d-d9703ea2ff3e
# 9   2baf3abb-bc1b-419f-8a45-0003d6f914c4
# 10  be29db96-94cc-4491-8aec-744ed004e964
# 11  0ed750c7-d63e-40ea-b46a-fbd792bdae8c
# 12  5dc04125-bf61-42f5-8697-502dff8b0493
# 13  f6989083-1daf-40f5-b08e-604cb10f5679
# 14  9ad9dffc-3b99-4b8f-a611-7bdbc5c64e32
# 15  d2e11475-382a-4c22-ac7d-682778a76d3e
# 16  fa88feea-258f-48f7-a257-2d79fd8e3a19
# 17  0b2fb3a3-f2b0-4ab6-a649-c59b6b78e696
# 18  38006f3e-7cfc-40bc-9a65-ce075a505078
# 19  07fa1325-2f33-4c78-aeff-b422f6f4ff76
# 20  c951446f-76e4-4baa-914c-85a88b4e6484
# 21  097a0481-0741-493f-ba27-061709e11b10
# 22  b5375a4e-38ec-4d84-bc6f-ba10413456b4
# 23  6a7fa881-5dd2-4bb6-aca2-943af2b95658
# 24  2b48b446-1851-487b-a7ca-205f46f8434b
# 25  24beecef-d059-4ef0-b9a5-cae4d2c0d60e
# 26  d01fecb5-b277-4129-85d8-d113c11c3739
# 27  8a85751b-bac0-4f90-b9fb-9e272f87ddf3
# 28  8f597964-182b-4b5f-9600-84b41f5ed03b
# 29  7f56bfd2-c0b0-485a-b7e0-efddb74658a2
# 30  26304315-b088-4e0f-a848-5fb014ca3789
# 31  6ee5e324-eebd-4bb7-8c1c-fe960fbf1185
# 32  2f75487a-a56c-4e9f-9629-306de904d39c
# 33  3e7b0335-f677-47c7-a044-9ab716bd6f97
# 34  f929e8a7-4149-4415-8515-4d1326556ae0
# 35  adc06450-e731-4505-a9fd-3737eac5560e
# 36  34cb94c5-e33a-4860-be7e-c6223c84545c
# 37  c8cc81e3-c022-46e5-9327-3048ff8bb89b
# 38  5d03a3e2-4e1d-4835-92a8-47c023121081
# 39  2eabab17-55a3-48a7-a468-785b39a86d47
#
#                                              entities  \
# 0   {'PROBLEM': ['radiculopathy', 'the pain', 'wea...
# 1   {'PROBLEM': ['known sick contacts', 'flu - lik...
# 2   {'PROBLEM': ['known allergies'], 'TREATMENT': ...
# 3   {'PROBLEM': ['hee', 'sp', 'blood', 'symptoms',...
# 4   {'PROBLEM': ['significant stress', 'chronic co...
# 5   {'PROBLEM': [], 'TREATMENT': ['the ant bait', ...
# 6   {'PROBLEM': ['allergies', 'drug allergies'], '...
# 7   {'PROBLEM': ['lightheadedness', 'lesterol prob...
# 8   {'PROBLEM': ['ha', 'red', 'systemic symptoms',...
# 9   {'PROBLEM': ['previous knee injury', 'wet coug...
# 10  {'PROBLEM': [], 'TREATMENT': [], 'TEST': ['cli...
# 11  {'PROBLEM': [], 'TREATMENT': ['medications', '...
# 12  {'PROBLEM': ['cancer', 'high blood pressure', ...
# 13  {'PROBLEM': [], 'TREATMENT': ['a tetanus shot'...
# 14  {'PROBLEM': ['heart vessel blockage', 'heart d...
# 15  {'PROBLEM': ['swollen glands', 'any other bloo...
# 16  {'PROBLEM': ['lightheadedness', 'the dizziness...
# 17  {'PROBLEM': [], 'TREATMENT': [], 'TEST': ['imp...
# 18  {'PROBLEM': ['red', 'tenderness over medial el...
# 19  {'PROBLEM': ['swelling', 'ness of breath', 'at...
# 20  {'PROBLEM': ['ry / fecal incontinence', 'mild ...
# 21  {'PROBLEM': ['diabetes', 'high blood pressure'...
# 22  {'PROBLEM': ['discomfort', 'pain'], 'TREATMENT...
# 23  {'PROBLEM': ['all', 'asthma'], 'TREATMENT': ['...
# 24  {'PROBLEM': ['chest pain', 'fever'], 'TREATMEN...
# 25  {'PROBLEM': ['heart issues', 'diabetes ( sugar...
# 26  {'PROBLEM': ['self - harm', 'depressed', 'alle...
# 27  {'PROBLEM': [], 'TREATMENT': ['medications'], ...
# 28  {'PROBLEM': ['dull pain in the upper outer', '...
# 29  {'PROBLEM': ['sharp chest pain', 'faint', 's',...
# 30  {'PROBLEM': ['a cerebrovascular accident', 'di...
# 31  {'PROBLEM': ['left knee'], 'TREATMENT': ['a kn...
# 32  {'PROBLEM': ['breast cancer', 'abnormal pap sm...
# 33  {'PROBLEM': ['difficulty'], 'TREATMENT': ['med...
# 34  {'PROBLEM': ['betic', 'dia'], 'TREATMENT': ['m...
# 35       {'PROBLEM': [], 'TREATMENT': [], 'TEST': []}
# 36  {'PROBLEM': ['diabetes', 'heart disease'], 'TR...
# 37  {'PROBLEM': ['gement of left testicle', 'yello...
# 38  {'PROBLEM': ['hoarseness worsening', 'hee', 's...
# 39       {'PROBLEM': [], 'TREATMENT': [], 'TEST': []}
#
#                                              problems  \
# 0   [radiculopathy, the pain, weakness in the legs...
# 1   [known sick contacts, flu - like illness, ning...
# 2                                   [known allergies]
# 3   [hee, sp, blood, symptoms, w, um, viral infect...
# 4   [significant stress, chronic conditions, curre...
# 5                                                  []
# 6                         [allergies, drug allergies]
# 7   [lightheadedness, lesterol problems, cancers, ...
# 8   [ha, red, systemic symptoms, w, ope, ty, pcn a...
# 9   [previous knee injury, wet cough, pati, as, he...
# 10                                                 []
# 11                                                 []
# 12  [cancer, high blood pressure, heart disease, c...
# 13                                                 []
# 14             [heart vessel blockage, heart disease]
# 15  [swollen glands, any other blood disorders, an...
# 16  [lightheadedness, the dizziness, s, general di...
# 17                                                 []
# 18  [red, tenderness over medial elbow, forearm, c...
# 19  [swelling, ness of breath, ations, heart attac...
# 20  [ry / fecal incontinence, mild tingling sensat...
# 21     [diabetes, high blood pressure, heart disease]
# 22                                 [discomfort, pain]
# 23                                      [all, asthma]
# 24                                [chest pain, fever]
# 25         [heart issues, diabetes ( sugar problem )]
# 26  [self - harm, depressed, aller, emotional diff...
# 27                                                 []
# 28  [dull pain in the upper outer, persistent pain...
# 29  [sharp chest pain, faint, s, cl, pati, clot, h...
# 30    [a cerebrovascular accident, diabetes mellitus]
# 31                                        [left knee]
# 32               [breast cancer, abnormal pap smears]
# 33                                       [difficulty]
# 34                                       [betic, dia]
# 35                                                 []
# 36                          [diabetes, heart disease]
# 37  [gement of left testicle, yellow fluid dischar...
# 38  [hoarseness worsening, hee, sp, viral laryngit...
# 39                                                 []
#
#                                            treatments  \
# 0   [anti - inflammatory medications, treatments, ...
# 1   [appendect, omy, infection control measures, o...
# 2                                       [medications]
# 3                                      [multivitamin]
# 4                 [advil, tu, ms, tylenol, treatment]
# 5        [the ant bait, borax, ant bait, medications]
# 6                                                  []
# 7   [recent hospitalisations, medications, prior s...
# 8                    [abx, ce, amoxicillin, furoxime]
# 9   [left knee replacement, antibiotics, statin, a...
# 10                                                 []
# 11                           [medications, surgeries]
# 12                                                 []
# 13                                   [a tetanus shot]
# 14                                                 []
# 15                                                 []
# 16                                                 []
# 17                                                 []
# 18  [a line, ice, nsaids, compression sleeve, topi...
# 19                                      [medications]
# 20  [calcium, hospitalizations, back protection te...
# 21                                    [any surgeries]
# 22                                                 []
# 23                                  [in, the inhaler]
# 24                                                 []
# 25                                                 []
# 26                                                 []
# 27                                      [medications]
# 28                [roid injection, medrol packs, ste]
# 29     [current treatment, surgery, pain medications]
# 30                              [diabetes management]
# 31                          [a knee brace, treatment]
# 32                                                 []
# 33                                      [medications]
# 34                             [medications, insulin]
# 35                                                 []
# 36                                                 []
# 37                    [previous antibiotic treatment]
# 38  [ries, antibiotics, salt water gargles, medica...
# 39                                                 []
#
#                                                 tests
# 0   [differential diagnoses, x - rays of the lower...
# 1                          [sw, covid, swab, testing]
# 2                                                  []
# 3                          [covid, swab, temperature]
# 4   [physical examination, s signs, vital, assessm...
# 5                                                  []
# 6                                                  []
# 7                  [physical exam, assessment, vital]
# 8                                   [ear exam, vital]
# 9   [ups, age - appropriate screenings, ray, vital...
# 10                 [clinical impressions, assessment]
# 11                                                 []
# 12                                       [assessment]
# 13                                                 []
# 14                                       [assessment]
# 15                                       [assessment]
# 16  [evaluation, formal assessment, blood sugar le...
# 17                                      [impressions]
# 18  [imaging, travel assessment, pati, pal, on ove...
# 19                                            [tests]
# 20  [x, imaging, mri of lumbar spine, palpation, l...
# 21                                       [assessment]
# 22                                       [assessment]
# 23                                                 []
# 24                                                 []
# 25                                       [assessment]
# 26                                                 []
# 27                                                 []
# 28                                 [blood sugar, mri]
# 29  [imaging, physical examination, blood work, fu...
# 30  [blood test, the blood test, a blood test, mon...
# 31                                                 []
# 32                         [impressions, a mammogram]
# 33                                                 []
# 34                                                 []
# 35                                                 []
# 36                                       [assessment]
# 37                      [assessment, potassium level]
# 38  [inspection of throat, discharge assessment, i...
# 39                                                 []

# %%
# Saving the processed DataFrame to a CSV file
csv_file_path = 'processed_output.csv'  # Specify your desired file path
processed_df.to_csv(csv_file_path, index=False)  # Set index=False if you don't want to include row indices in the file
print(f"Data saved to {csv_file_path}")
# Out:
# Data saved to processed_output.csv
